# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
quality = ctrl.Antecedent(np.arange(0, 21, 1), "quality")
service = ctrl.Antecedent(np.arange(0, 21, 1), "service")
tip = ctrl.Consequent(np.arange(0, 26, 1), "tip")

# %%
quality.automf(3)
service.automf(3)

# %%
quality["average"].view()
# Out:
# /home/orangefrodo/.local/lib/python3.8/site-packages/skfuzzy/control/term.py:74: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
